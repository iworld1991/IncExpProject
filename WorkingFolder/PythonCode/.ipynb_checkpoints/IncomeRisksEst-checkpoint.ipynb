# %% [markdown]
# ## Income Risks Estimation
#
# This noteobok contains the following
#
#  - Estimation functions of time-varying income risks for an integrated moving average process of income/earnings
#  - It allows for different assumptions about expectations, ranging from rational expectation to alternative assumptions.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import copy as cp

# %%
from IncomeProcess import IMAProcess as ima

# %%
## debugging test of the data 

t = 50
ma_nosa = np.array([1])
p_sigmas = np.arange(t)  # sizes of the time-varying permanent volatility 
p_sigmas_rw = np.ones(t) # a special case of time-invariant permanent volatility, random walk 
p_sigmas_draw = np.random.uniform(0,1,t) ## allowing for time-variant shocks 

pt_ratio = 0.33
t_sigmas = pt_ratio * p_sigmas_draw # sizes of the time-varyingpermanent volatility
sigmas = np.array([p_sigmas_draw,
                   t_sigmas])

dt = ima(t = t,
                ma_coeffs = ma_nosa,
                sigmas = sigmas)
sim_data = dt.SimulateSeries(n_sim = 5000)
sim_moms = dt.SimulatedMoments()

# %%
## get the computed moments 

comp_moms = dt.ComputeGenMoments()

av_comp = comp_moms['Mean']
cov_var_comp = comp_moms['Var']
var_comp = dt.AutocovarComp(step=0) #np.diagonal(cov_var_comp)
autovarb1_comp = dt.AutocovarComp(step=-1)  #np.array([cov_var_comp[i,i+1] for i in range(len(cov_var_comp)-1)])

# %%
## get the simulated moments 
av = sim_moms['Mean']
cov_var = sim_moms['Var']
var = dt.Autocovar(step = 0)   #= np.diagonal(cov_var)
autovarb1 = dt.Autocovar(step = -1) #np.array([cov_var[i,i+1] for i in range(len(cov_var)-1)])

# %%
## plot simulated moments of first diff 

plt.figure(figsize=((20,4)))

plt.subplot(1,4,1)
plt.title(r'$\sigma_{\theta,t},\sigma_{\epsilon,t}$')
plt.plot(p_sigmas_draw,label='sigma_p')
plt.plot(t_sigmas,label='sigma_t')
plt.legend(loc=0)

plt.subplot(1,4,2)
plt.title(r'$\Delta(y_t)$')
plt.plot(av,label='simulated')
plt.plot(av_comp,label='computed')
plt.legend(loc=0)

plt.subplot(1,4,3)
plt.title(r'$Var(\Delta y_t)$')
plt.plot(var,label='simulated')
plt.plot(var_comp,label='computed')
plt.legend(loc=0)

plt.subplot(1,4,4)
plt.title(r'$Cov(\Delta y_t,\Delta y_{t+1})$')
plt.plot(autovarb1,label='simulated')
plt.plot(autovarb1_comp,label='computed')
plt.legend(loc = 0)

# %%
## robustness check if the transitory risks is approximately equal to the assigned level

sigma_t_est = np.array(np.sqrt(abs(autovarb1)))
plt.plot(sigma_t_est,'r-',label=r'$\widehat \sigma_{\theta,t}$')
plt.plot(t_sigmas[1:],'b-.',label=r'$\sigma_{\theta,t}$')
plt.legend(loc=1)

# %% [markdown]
# ### Time Aggregation

# %%
## time aggregation 

sim_data = dt.SimulateSeries(n_sim = 1000)
agg_series = dt.TimeAggregate(n_periods = 2)
agg_series_moms = dt.SimulateMomentsAgg()

# %%
## difference times degree of time aggregation leads to different autocorrelation
for ns in np.array([2,8]):
    an_instance = cp.deepcopy(dt)
    series = an_instance.SimulateSeries(n_sim =500)
    agg_series = an_instance.TimeAggregate(n_periods = ns)
    agg_series_moms = an_instance.SimulateMomentsAgg()
    var_sim = an_instance.AutocovarAgg(step=0)
    var_b1 = an_instance.AutocovarAgg(step=-1)
    plt.plot(var_b1,label=r'={}'.format(ns))
plt.legend(loc=1)

# %% [markdown]
# ### Estimation

# %%
## some fake data moments with alternative parameters

pt_ratio_fake = 0.6
t_sigmas = pt_ratio_fake * p_sigmas_draw # sizes of the time-varyingpermanent volatility
sigmas = np.array([p_sigmas_draw,
                   t_sigmas])

dt_fake = ima(t = t,
                     ma_coeffs = ma_nosa,
                     sigmas = sigmas)
data_fake = dt_fake.SimulateSeries(n_sim = 5000)
moms_fake = dt_fake.SimulatedMoments()

# %% [markdown]
# #### Estimation using computed moments

# %%
## estimation of income risks 

dt_est = cp.deepcopy(dt)
dt_est.GetDataMoments(moms_fake)

# %%
para_est = dt_est.EstimatePara(method='CG',
                              para_guess = (np.array([1]),
                                           np.random.uniform(0,1,100).reshape(2,50)
                                           ))
# Out:
# Optimization terminated successfully.
#          Current function value: 3.667041
#          Iterations: 5
#          Function evaluations: 80
#          Gradient evaluations: 19

# %%
## check the estimation and true parameters 

fig = plt.figure(figsize=([10,4]))

plt.subplot(1,2,1)
plt.title('Permanent Risk')
plt.plot(dt_est.para_est[1][0].T**2,'r-',label='Estimation')
plt.plot(dt_fake.sigmas[0]**2,'-*',label='Truth')


plt.subplot(1,2,2)
plt.title('Transitory Risk')
plt.plot(dt_est.para_est[1][1].T**2,'r-',label='Estimation')
plt.plot(dt_fake.sigmas[1]**2,'-*',label='Truth')
plt.legend(loc=0)

# %% [markdown]
# #### Estimation using simulated moments

# %%
para_est_sim = dt_est.EstimateParabySim()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.704297
#          Iterations: 0
#          Function evaluations: 80
#          Gradient evaluations: 17

# %%
## check the estimation and true parameters

fig = plt.figure(figsize=([10,4]))

plt.subplot(1,2,1)
plt.title('Permanent Risk')
plt.plot(dt_est.para_est_sim[1][0].T**2,'r-',label='Estimation(sim)')
plt.plot(dt_fake.sigmas[0]**2,'-*',label='Truth')


plt.subplot(1,2,2)
plt.title('Transitory Risk')
plt.plot(dt_est.para_est_sim[1][1].T**2,'r-',label='Estimation(sim)')
plt.plot(dt_fake.sigmas[1]**2,'-*',label='Truth')
plt.legend(loc=0)

# %%
### reapeating the estimation for many times

n_loop = 10

para_est_sum_sim = (np.array([0]),np.zeros([2,50]))
for i in range(n_loop):
    para_est_this_time = abs(dt_est.EstimateParabySim(method='CG'))
    para_est_sum_sim = para_est_sum_sim + para_est_this_time
    
para_est_av = para_est_sum_sim/n_loop
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.374909
#          Iterations: 1
#          Function evaluations: 84
#          Gradient evaluations: 18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-2f17461fc636> in <module>
#       5 para_est_sum_sim = (np.array([0]),np.zeros([2,50]))
#       6 for i in range(n_loop):
# ----> 7     para_est_this_time = abs(dt_est.EstimateParabySim(method='CG'))
#       8     para_est_sum_sim = para_est_sum_sim + para_est_this_time
#       9
#
# ~/Dropbox/IncExpProject/WorkingFolder/PythonCode/IncomeProcess.py in EstimateParabySim(self, method, bounds, para_guess, options)
#     202                             x0 = para_guess,
#     203                             method = method,
# --> 204                             bounds = bounds,
#     205                             options = options)['x']
#     206
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     591         return _minimize_powell(fun, x0, args, callback, **options)
#     592     elif meth == 'cg':
# --> 593         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     594     elif meth == 'bfgs':
#     595         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in _minimize_cg(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#    1322                      _line_search_wolfe12(f, myfprime, xk, pk, gfk, old_fval,
#    1323                                           old_old_fval, c2=0.4, amin=1e-100, amax=1e100,
# -> 1324                                           extra_condition=descent_condition)
#    1325         except _LineSearchError:
#    1326             # Line search failed to find a better solution.
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#     808     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#     809                              old_fval, old_old_fval,
# --> 810                              **kwargs)
#     811
#     812     if ret[0] is not None and extra_condition is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      99     stp, fval, old_fval = scalar_search_wolfe1(
#     100             phi, derphi, old_fval, old_old_fval, derphi0,
# --> 101             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#     102
#     103     return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     172         if task[:2] == b'FG':
#     173             alpha1 = stp
# --> 174             phi1 = phi(stp)
#     175             derphi1 = derphi(stp)
#     176         else:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/linesearch.py in phi(s)
#      85     def phi(s):
#      86         fc[0] += 1
# ---> 87         return f(xk + s*pk, *args)
#      88
#      89     def derphi(s):
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ~/Dropbox/IncExpProject/WorkingFolder/PythonCode/IncomeProcess.py in ObjFuncSim(self, para_sim)
#     185         self.ma_coeffs = ma_coeffs
#     186         self.sigmas = sigmas
# --> 187         model_series_sim = self.SimulateSeries()
#     188         model_moms_dct = self.SimulatedMoments()
#     189         model_moms = np.array([model_moms_dct[key] for key in ['Var']]).flatten()
#
# ~/Dropbox/IncExpProject/WorkingFolder/PythonCode/IncomeProcess.py in SimulatedMoments(self)
#      82         ## moments of first diff
#      83         mean_diff = np.mean(diff,axis = 0)
# ---> 84         varcov_diff = np.cov(diff.T)
#      85
#      86         self.SimMoms = {'Mean':mean_diff,
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2448     else:
#    2449         X_T = (X*w).T
# -> 2450     c = dot(X, X_T.conj())
#    2451     c *= np.true_divide(1, fact)
#    2452     return c.squeeze()
#
# KeyboardInterrupt:

# %%
## check the estimation and true parameters

fig = plt.figure(figsize=([14,4]))

plt.subplot(1,2,1)
plt.title('Permanent Risk')
plt.plot(para_est_av[1][0].T**2,'r-',label='Estimation(sim)')
plt.plot(dt_fake.sigmas[0]**2,'-*',label='Truth')


plt.subplot(1,2,2)
plt.title('Transitory Risk')
plt.plot(para_est_av[1][1].T**2,'r-',label='Estimation(sim)')
plt.plot(dt_fake.sigmas[1]**2,'-*',label='Truth')
plt.legend(loc=0)

# %% [markdown]
# #### Estimation using time aggregated data

# %%
## get some fake aggregated data moments
moms_agg_fake = dt_fake.TimeAggregate()
moms_agg_dct_fake = dt_fake.SimulateMomentsAgg()

# %%
## estimation 
dt_est.GetDataMomentsAgg(moms_agg_dct_fake)
para_est_agg = dt_est.EstimateParaAgg()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 86.934117
#          Iterations: 1
#          Function evaluations: 111
#          Gradient evaluations: 25

# %%
## check the estimation and true parameters

fig = plt.figure(figsize=([10,4]))

plt.subplot(1,2,1)
plt.title('Permanent Risk')
plt.plot(dt_est.para_est_agg[1][0].T**2,'r-',label='Estimation(agg)')
plt.plot(dt_fake.sigmas[0]**2,'-*',label='Truth')

plt.subplot(1,2,2)
plt.title('Transitory Risk')
plt.plot(dt_est.para_est_agg[1][1].T**2,'r-',label='Estimation(agg)')
plt.plot(dt_fake.sigmas[1]**2,'-*',label='Truth')
plt.legend(loc=0)

# %%
### reapeating the estimation for many times

n_loop = 20

para_est_sum_agg = (np.array([0]),np.zeros([2,50]))
for i in range(n_loop):
    para_est_this_time = abs(dt_est.EstimateParaAgg(method='CG'))
    para_est_sum_agg = para_est_sum_agg + para_est_this_time
    
para_est_av_agg = para_est_sum_agg/n_loop
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 63.368001
#          Iterations: 2
#          Function evaluations: 107
#          Gradient evaluations: 24
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 58.986194
#          Iterations: 1
#          Function evaluations: 139
#          Gradient evaluations: 32
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 58.624810
#          Iterations: 1
#          Function evaluations: 87
#          Gradient evaluations: 19
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59.153579
#          Iterations: 3
#          Function evaluations: 164
#          Gradient evaluations: 34
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 66.365829
#          Iterations: 0
#          Function evaluations: 120
#          Gradient evaluations: 27
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 58.384179
#          Iterations: 2
#          Function evaluations: 120
#          Gradient evaluations: 27
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 63.275220
#          Iterations: 0
#          Function evaluations: 100
#          Gradient evaluations: 22
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 63.725594
#          Iterations: 1
#          Function evaluations: 134
#          Gradient evaluations: 31
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 62.657477
#          Iterations: 0
#          Function evaluations: 104
#          Gradient evaluations: 23
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59.702099
#          Iterations: 1
#          Function evaluations: 87
#          Gradient evaluations: 19
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 61.106603
#          Iterations: 1
#          Function evaluations: 87
#          Gradient evaluations: 19
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 61.761544
#          Iterations: 1
#          Function evaluations: 83
#          Gradient evaluations: 18
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 66.882033
#          Iterations: 2
#          Function evaluations: 163
#          Gradient evaluations: 38
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64.411428
#          Iterations: 0
#          Function evaluations: 104
#          Gradient evaluations: 23
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59.352349
#          Iterations: 3
#          Function evaluations: 157
#          Gradient evaluations: 36
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 62.364067
#          Iterations: 0
#          Function evaluations: 112
#          Gradient evaluations: 25
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 58.238142
#          Iterations: 1
#          Function evaluations: 95
#          Gradient evaluations: 21
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 64.623600
#          Iterations: 1
#          Function evaluations: 101
#          Gradient evaluations: 23
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 59.047860
#          Iterations: 1
#          Function evaluations: 110
#          Gradient evaluations: 25
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 61.416538
#          Iterations: 0
#          Function evaluations: 104
#          Gradient evaluations: 23

# %%
## check the estimation and true parameters

fig = plt.figure(figsize=([10,4]))

plt.subplot(1,2,1)
plt.title('Permanent Risk')
plt.plot(para_est_av_agg[1][0].T**2,'r-',label='Estimation(agg)')
plt.plot(dt_fake.sigmas[0]**2,'-*',label='Truth')

plt.subplot(1,2,2)
plt.title('Transitory Risk')
plt.plot(para_est_av_agg[1][1].T**2,'r-',label='Estimation(agg)')
plt.plot(dt_fake.sigmas[1]**2,'-*',label='Truth')
plt.legend(loc=0)
