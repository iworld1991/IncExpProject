# %% [markdown]
# ## Perceived Labor Income Risks and Asset Returns
#
# - This notebook first downloads asset return indicators
# - Then we examine the correlation of higher moments of labor income risks and asset returns

# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns

# %% [markdown]
# ###  1. Download stock return series

# %%
## s&p 500 series 

start = datetime.datetime(2000, 1, 1)
end = datetime.datetime(2019, 10, 30)

# %%
## downloading the data from Fred
sp500D= web.DataReader('sp500', 'fred', start, end)

# %%
#plotting
sp500D.plot(lw=2)
sp500plt = plt.title('S&P 500')

# %%
## collapse to monthly data 
sp500D.index = pd.to_datetime(sp500D.index)
sp500M = sp500D.resample('M').last()

# %%
sp500M.plot(lw=2)
sp500Mplt = plt.title('S&P 500 (end of month)')

# %%
sp500MR = np.log(sp500M).diff()

# %%
sp500MR.plot()
sp500MRplt = plt.title('Monthly return of S&P 500')

# %% [markdown]
# ###  2. Loading and cleaning perceived income series

# %%
## loading the stata file
SCEProbIndM = pd.read_stata('../SurveyData/SCE/IncExpSCEProbIndM.dta')

# %%
## subselect the dataframe
sub_var = ['date','userid','Q24_var','Q24_mean','Q24_iqr']
IncSCEIndMoms = SCEProbIndM[sub_var]

## drop nan observations
IncSCEIndMoms = IncSCEIndMoms.dropna(how='any')

# %%
## turn the data into a panel 
#IncSCEIndMomsPN = IncSCEIndMoms.pivot_table(values = ['Q24_mean','Q24_var','Q24_iqr'],
#                                            index = ['date'],
#                                            columns = ['userid'])

# %%
## compute population summary stats for these ind moms
IncSCEPopMomsMed = pd.pivot_table(data = IncSCEIndMoms, index=['date'], 
                                  values = ['Q24_mean','Q24_var','Q24_iqr'],
                                  aggfunc= 'median').reset_index().rename(columns={'Q24_mean': 'meanMed', 
                                                                                   'Q24_var': 'varMed',
                                                                                  'Q24_iqr': 'iqrMed'})

IncSCEPopMomsMean = pd.pivot_table(data = IncSCEIndMoms, index=['date'], 
                                  values = ['Q24_mean','Q24_var','Q24_iqr'],
                                  aggfunc= 'mean').reset_index().rename(columns={'Q24_mean': 'meanMean', 
                                                                                   'Q24_var': 'varMean',
                                                                                  'Q24_iqr': 'iqrMean'})

# %%
## streamline the dates for merging 

dateM1= pd.to_datetime(sp500MR.index,format='%Y%m%d')
# adjusting the end-of-month dates to the begining-of-month for combining 
sp500MR.index = sp500MR.index.shift(1,freq='D') 

IncSCEPopMomsMed.index = pd.DatetimeIndex(IncSCEPopMomsMed['date'] ,freq='infer')
IncSCEPopMomsMean.index = pd.DatetimeIndex(IncSCEPopMomsMean['date'] ,freq='infer')

# %% [markdown]
# ### 3. Combinine the two series

# %%
dt_combM = pd.concat([sp500MR,
                      IncSCEPopMomsMed,
                      IncSCEPopMomsMean],
                     join="inner",axis=1).drop(columns=['date'])

# %%
dt_combM.head()
# Out:
#                sp500    iqrMed   meanMed    varMed   iqrMean  meanMean  \
# 2013-06-01  0.020550  1.214923  2.367884  0.813287  2.130622  2.733790
# 2013-07-01 -0.015113  1.171573  2.119277  0.666667  2.002637  2.586685
# 2013-08-01  0.048278  1.171573  2.367884  0.666667  2.136908  2.848078
# 2013-09-01 -0.031798  1.171573  2.033243  0.666667  2.136814  2.729330
# 2013-10-01  0.029316  1.171573  2.261509  0.666667  2.123605  2.753134
#
#              varMean
# 2013-06-01  3.693810
# 2013-07-01  3.253502
# 2013-08-01  3.908042
# 2013-09-01  3.744147
# 2013-10-01  3.681164

# %%
dt_combM.corr()
# Out:
#              sp500    iqrMed   meanMed    varMed   iqrMean  meanMean   varMean
# sp500     1.000000  0.027383  0.066983  0.038296  0.205504  0.023421  0.238351
# iqrMed    0.027383  1.000000  0.535100  0.978577  0.677793  0.624292  0.553698
# meanMed   0.066983  0.535100  1.000000  0.576011  0.562634  0.892212  0.494610
# varMed    0.038296  0.978577  0.576011  1.000000  0.708331  0.650671  0.569874
# iqrMean   0.205504  0.677793  0.562634  0.708331  1.000000  0.671001  0.952194
# meanMean  0.023421  0.624292  0.892212  0.650671  0.671001  1.000000  0.550117
# varMean   0.238351  0.553698  0.494610  0.569874  0.952194  0.550117  1.000000

# %%
## plots of correlation 

for i,moms in enumerate( ['mean','var','iqr']):
    fig, ax = plt.subplots()
    ax2 = ax.twinx()
    ax.bar(dt_combM.index, dt_combM['sp500'], color='gray', width=25,label='SP500')
    ax2.plot(dt_combM[str(moms)+'Med'], 'r--',label=str(moms)+' (RHS)')
    #ax.set_xticklabels(dt_combM.index)
    ax.legend(loc=0)
    ax2.legend(loc=2)

# %%
## moving average 

dt_combM3mv = dt_combM.rolling(3).mean()

# %%
dt_combM3mv.corr()
# Out:
#              sp500    iqrMed   meanMed    varMed   iqrMean  meanMean   varMean
# sp500     1.000000 -0.196317 -0.226147 -0.199832  0.030097 -0.251791  0.129448
# iqrMed   -0.196317  1.000000  0.611295  0.991191  0.758579  0.759943  0.618375
# meanMed  -0.226147  0.611295  1.000000  0.633077  0.585718  0.915485  0.542583
# varMed   -0.199832  0.991191  0.633077  1.000000  0.799803  0.770918  0.663997
# iqrMean   0.030097  0.758579  0.585718  0.799803  1.000000  0.724525  0.959788
# meanMean -0.251791  0.759943  0.915485  0.770918  0.724525  1.000000  0.622469
# varMean   0.129448  0.618375  0.542583  0.663997  0.959788  0.622469  1.000000

# %%
## plots of correlation for 3-month moving average 

for i,moms in enumerate( ['mean','var','iqr']):
    fig, ax = plt.subplots()
    ax2 = ax.twinx()
    ax.bar(dt_combM3mv.index, dt_combM['sp500'], color='gray', width=25,label='SP500')
    ax2.plot(dt_combM3mv[str(moms)+'Med'], 'r--',label=str(moms)+' (RHS)')
    #ax.set_xticklabels(dt_combM.index)
    ax.legend(loc=0)
    ax2.legend(loc=2)
