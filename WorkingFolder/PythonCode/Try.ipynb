# %%
import numpy as np

# %%
for i in range(10):
    print(i)
    while True:
        try:
            x = i + np.random.randn(1)
            print(x)
            print(np.log(x))
        except:
            break
# Out:
# 0
# [0.15168221]
# [-1.88596764]
# [0.27791027]
# [-1.280457]
# [0.82009015]
# [-0.19834101]
# [1.2602967]
# [0.23134717]
# [-0.40741105]
# [nan]
# [0.99886715]
# [-0.00113349]
# [0.36057131]
# [-1.02006554]
# [-0.23080265]
# [nan]
# [-1.11500783]
# [nan]
# [-0.00194214]
# [nan]
# [-0.27403858]
# [nan]
# [0.25901655]
# [-1.35086333]
# [0.80829309]
# [-0.21283054]
# [-1.47318568]
# [nan]
# [2.34083416]
# [0.85050734]
# [1.67161728]
# [0.51379159]
# [1.30604137]
# [0.26700071]
# [-0.20436616]
# [nan]
# [0.34623717]
# [-1.06063128]
# [0.26354839]
# [-1.3335183]
# [-1.52686235]
# [nan]
# [-0.29436093]
# [nan]
# [0.51300246]
# [-0.66747464]
# [1.58634434]
# [0.46143221]
# [0.51479199]
# [-0.66399237]
# [-1.17732118]
# [nan]
# [1.46149763]
# [0.37946168]
# [-0.92990738]
# [nan]
# [0.77004379]
# [-0.26130789]
# [2.28739376]
# [0.82741307]
# [-0.53392364]
# [nan]
# [1.86100115]
# [0.62111459]
# [-1.5673191]
# [nan]
# [0.71096117]
# [-0.34113747]
# [1.62169795]
# [0.48347372]
# [-0.10329647]
# ...
